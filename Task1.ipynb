# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score
from sklearn.preprocessing import label_binarize

df = pd.read_csv("train.csv",index_col='id')
print('Shape:',df.shape)
df.head()
# Out:
# Shape: (99872, 33)
#          player_id  kill_death_ratio  headshot_percentage   win_rate  \
# id
# PLY00001   P058048          4.556072            15.494589        NaN
# PLY00002   P037400          6.177695            51.476210  86.670187
# PLY00003   P001054          6.584511            51.692578  32.827778
# PLY00004   P062710          5.237014            44.181842  62.740475
# PLY00005   P068548          2.453744            44.361101  68.296046
#
#           accuracy_score  kill_consistency  reaction_time_ms  \
# id
# PLY00001       36.953785          0.737653               NaN
# PLY00002       59.946064               NaN         93.748524
# PLY00003       46.545739          0.811803        120.895839
# PLY00004       30.260066          0.345491        248.056545
# PLY00005       27.470153          0.851962        210.530688
#
#           account_age_days      level  level_progression_speed  ...  \
# id                                                              ...
# PLY00001       1204.586641  73.364603                 0.033039  ...
# PLY00002          3.405453  84.104334                12.211503  ...
# PLY00003        551.221686  43.803175                 0.076185  ...
# PLY00004        114.034430        NaN                      NaN  ...
# PLY00005        153.210944  83.293728                 0.354636  ...
#
#           team_play_score  buy_decision_score  map_knowledge  \
# id
# PLY00001         0.653589            0.860407       0.487273
# PLY00002              NaN            0.410925       0.690833
# PLY00003         0.639732            0.619968       0.511507
# PLY00004         0.766887            0.612241       0.477374
# PLY00005         0.691935            0.653540       0.698389
#
#           clutch_success_rate  first_blood_rate  survival_time_avg  \
# id
# PLY00001             0.534021          0.321734                NaN
# PLY00002             0.151872          0.462196          84.599562
# PLY00003             0.311445          0.270611          83.793333
# PLY00004                  NaN          0.402723          97.518653
# PLY00005                  NaN          0.197220          50.405967
#
#           damage_per_round  utility_usage_rate  crosshair_placement  \
# id
# PLY00001         91.517681            0.736361             0.928522
# PLY00002        119.212421            0.525739             0.946558
# PLY00003         58.200726            0.739374             0.897872
# PLY00004        121.315491            0.531533             0.860302
# PLY00005         79.110571            0.771739             0.853758
#
#           is_cheater
# id
# PLY00001         0.0
# PLY00002         0.0
# PLY00003         0.0
# PLY00004         1.0
# PLY00005         1.0
#
# [5 rows x 33 columns]

# %%
df
# Out:
#          player_id  kill_death_ratio  headshot_percentage   win_rate  \
# id
# PLY00001   P058048          4.556072            15.494589        NaN
# PLY00002   P037400          6.177695            51.476210  86.670187
# PLY00003   P001054          6.584511            51.692578  32.827778
# PLY00004   P062710          5.237014            44.181842  62.740475
# PLY00005   P068548          2.453744            44.361101  68.296046
# ...            ...               ...                  ...        ...
# PLY99868   P007977          2.601222                  NaN  83.232776
# PLY99869   P075394          5.058116            48.356105  42.939196
# PLY99870   P102956          6.750750            40.844715  73.391939
# PLY99871   P004320               NaN            48.600307        NaN
# PLY99872   P117650          3.640094            50.499442  82.836409
#
#           accuracy_score  kill_consistency  reaction_time_ms  \
# id
# PLY00001       36.953785          0.737653               NaN
# PLY00002       59.946064               NaN         93.748524
# PLY00003       46.545739          0.811803        120.895839
# PLY00004       30.260066          0.345491        248.056545
# PLY00005       27.470153          0.851962        210.530688
# ...                  ...               ...               ...
# PLY99868       45.794777          0.879093        126.546080
# PLY99869       33.672977          0.721029        177.840086
# PLY99870       38.367624          0.511457         81.585748
# PLY99871       48.624808          0.566101               NaN
# PLY99872       45.441891          0.423760        291.464916
#
#           account_age_days      level  level_progression_speed  ...  \
# id                                                              ...
# PLY00001       1204.586641  73.364603                 0.033039  ...
# PLY00002          3.405453  84.104334                12.211503  ...
# PLY00003        551.221686  43.803175                 0.076185  ...
# PLY00004        114.034430        NaN                      NaN  ...
# PLY00005        153.210944  83.293728                 0.354636  ...
# ...                    ...        ...                      ...  ...
# PLY99868               NaN        NaN                 0.110230  ...
# PLY99869         71.392368  81.017518                 0.401281  ...
# PLY99870         95.113547        NaN                      NaN  ...
# PLY99871        343.402328        NaN                      NaN  ...
# PLY99872        625.255701  55.486272                 0.051025  ...
#
#           team_play_score  buy_decision_score  map_knowledge  \
# id
# PLY00001         0.653589            0.860407       0.487273
# PLY00002              NaN            0.410925       0.690833
# PLY00003         0.639732            0.619968       0.511507
# PLY00004         0.766887            0.612241       0.477374
# PLY00005         0.691935            0.653540       0.698389
# ...                   ...                 ...            ...
# PLY99868              NaN            0.872660       0.729407
# PLY99869         0.431514            0.462389       0.860743
# PLY99870         0.811648            0.707167       0.861697
# PLY99871              NaN            0.847882       0.776999
# PLY99872         0.483975            0.386345       0.590288
#
#           clutch_success_rate  first_blood_rate  survival_time_avg  \
# id
# PLY00001             0.534021          0.321734                NaN
# PLY00002             0.151872          0.462196          84.599562
# PLY00003             0.311445          0.270611          83.793333
# PLY00004                  NaN          0.402723          97.518653
# PLY00005                  NaN          0.197220          50.405967
# ...                       ...               ...                ...
# PLY99868             0.190032          0.256026          45.451299
# PLY99869                  NaN          0.334757          80.832958
# PLY99870             0.420981          0.393700          67.353376
# PLY99871             0.551161          0.225338          85.505326
# PLY99872             0.204373          0.126859                NaN
#
#           damage_per_round  utility_usage_rate  crosshair_placement  \
# id
# PLY00001         91.517681            0.736361             0.928522
# PLY00002        119.212421            0.525739             0.946558
# PLY00003         58.200726            0.739374             0.897872
# PLY00004        121.315491            0.531533             0.860302
# PLY00005         79.110571            0.771739             0.853758
# ...                    ...                 ...                  ...
# PLY99868         99.081877            0.429230             0.845380
# PLY99869        128.849539            0.813330             0.903129
# PLY99870         85.250592            0.301678             0.847462
# PLY99871         93.773603            0.692110                  NaN
# PLY99872        115.418429            0.516329             0.917754
#
#           is_cheater
# id
# PLY00001         0.0
# PLY00002         0.0
# PLY00003         0.0
# PLY00004         1.0
# PLY00005         1.0
# ...              ...
# PLY99868         0.0
# PLY99869         0.0
# PLY99870         0.0
# PLY99871         1.0
# PLY99872         0.0
#
# [99872 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99872 entries, PLY00001 to PLY99872
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   player_id                99872 non-null  object
#  1   kill_death_ratio         97521 non-null  float64
#  2   headshot_percentage      84716 non-null  float64
#  3   win_rate                 90015 non-null  float64
#  4   accuracy_score           96848 non-null  float64
#  5   kill_consistency         97281 non-null  float64
#  6   reaction_time_ms         73815 non-null  float64
#  7   account_age_days         81323 non-null  float64
#  8   level                    75795 non-null  float64
#  9   level_progression_speed  80614 non-null  float64
#  10  friend_network_size      91713 non-null  float64
#  11  reports_received         75722 non-null  float64
#  12  device_changes_count     90774 non-null  float64
#  13  input_consistency_score  82273 non-null  float64
#  14  avg_session_length_min   94473 non-null  float64
#  15  sessions_per_day         83709 non-null  float64
#  16  night_play_ratio         91938 non-null  float64
#  17  weapon_switch_speed      86930 non-null  float64
#  18  movement_pattern_score   76000 non-null  float64
#  19  aiming_smoothness        99383 non-null  float64
#  20  spray_control_score      97855 non-null  float64
#  21  game_sense_score         77024 non-null  float64
#  22  communication_rate       83777 non-null  float64
#  23  team_play_score          84368 non-null  float64
#  24  buy_decision_score       92769 non-null  float64
#  25  map_knowledge            93165 non-null  float64
#  26  clutch_success_rate      74996 non-null  float64
#  27  first_blood_rate         97310 non-null  float64
#  28  survival_time_avg        83062 non-null  float64
#  29  damage_per_round         88684 non-null  float64
#  30  utility_usage_rate       97373 non-null  float64
#  31  crosshair_placement      93303 non-null  float64
#  32  is_cheater               97748 non-null  float64
# dtypes: float64(32), object(1)
# memory usage: 25.9+ MB

# %% [markdown]
# ## Prepare Data

# %%
df = df.dropna(subset=['is_cheater'])

# %%
y = df['is_cheater']
x = df.drop(columns=['is_cheater','player_id'])

# %%
print(y.isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Train/Test split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Identify Column types

# %%
num_cols = X_train.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = X_train.select_dtypes(exclude=[np.number]).columns.tolist()

# %% [markdown]
# ## Pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

numeric_proc = Pipeline([
    ('imputer', SimpleImputer(strategy='median'))
])
categorical_proc = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer([
    ('num', numeric_proc, num_cols),
    ('cat', categorical_proc, cat_cols)
])

# %% [markdown]
# ## Random Forest model + Pipeline

# %%
from sklearn.ensemble import RandomForestClassifier
model = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced'))
])

# %% [markdown]
# ## Hyperparameter search space

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

param_dist = {
    'classifier__n_estimators': [50, 100, 200],
    'classifier__max_depth': [None, 10, 20, 30],
    'classifier__min_samples_split': [2, 5, 10],
    'classifier__min_samples_leaf': [1, 2, 4],
    'classifier__max_features': ['auto', 'sqrt', 'log2']
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    n_iter=20, # Number of parameter settings that are sampled
    scoring='accuracy',
    cv=cv,
    verbose=2, # Show detailed output
    random_state=42,
    n_jobs=-1 # -1: Use all available cores 
)

search.fit(X_train, y_train)
print("Best parameters found: ", search.best_params_)
best_model = search.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\pipeline.py", line 662, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\pipeline.py", line 662, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.69540138 0.69583618 0.69912276        nan        nan 0.6951073
#  0.75035169 0.75440552        nan 0.69646282        nan        nan
#  0.75232105 0.69568277        nan 0.78051869 0.78227068 0.69636053
#         nan        nan]
#   warnings.warn(
# Best parameters found:  {'classifier__n_estimators': 200, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 4, 'classifier__max_features': 'sqrt', 'classifier__max_depth': 30}

# %% [markdown]
# ## Evaluate on test set

# %%
proba_test = best_model.predict_proba(X_test)[:, 1]
y_pred = (proba_test >= 0.5).astype(int)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
F2 = (5 * precision * recall) / (4 * precision + recall)
print(f"Test Set Metrics:\nAccuracy: {accuracy:.4f}\nPrecision: {precision:.4f}\nRecall: {recall:.4f}\nF2 Score: {F2:.4f}")
# Out:
# Test Set Metrics:
# Accuracy: 0.7836
# Precision: 0.6690
# Recall: 0.7339
# F2 Score: 0.7200

# %% [markdown]
# ## Save Model

# %%
import joblib
joblib.dump(best_model, 'task1_random_forest_model_v1.joblib')
print("Model saved as 'task1_random_forest_model_v1.joblib'")
# Out:
# Model saved as 'task1_random_forest_model_v1.joblib'
